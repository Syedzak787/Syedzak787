# %% [markdown]
# <a href="https://colab.research.google.com/github/Syedzak787/Syedzak787/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PW SKILLS Python workspace

# %%
pairs = []
for x in [1,2,3]:
    for y in [4,5,6]:
        pairs.append([x,y])
pairs
# Out:
# [[1, 4], [1, 5], [1, 6], [2, 4], [2, 5], [2, 6], [3, 4], [3, 5], [3, 6]]

# %%
#tuples and Sets
#Tuples -- Tuples are ordered collection of elements, heterogenous
#Tuples are immutable

t= ()
type(t)
# Out:
# tuple

# %%
t = ("pwskills", "syed", 1,2.3,3,4+5j)
t
# Out:
# ('pwskills', 'syed', 1, 2.3, 3, (4+5j))

# %%
t[0]
# Out:
# 'pwskills'

# %%
t[1]
# Out:
# 'syed'

# %%
t[0] =100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3802/665579404.py in <cell line: 0>()
# ----> 1 t[0] =100
#
# TypeError: 'tuple' object does not support item assignment

# %%
#use tuples as a  data structure where you dont want to modify the data

# %%
tuple = ("syed",1,1,2,3,"syed")
tuple.count("syed")
# Out:
# 2

# %%
tuple.count(1)
# Out:
# 2

# %%
tuple = (1,1,2,3,100,200,201)
max(tuple)
# Out:
# 201

# %%
#sets - Unordered and unique collection of elements
#doesnt allow duplciate elements
#unordered>> indexing will not work

# %%
s = {1,2,3,4}
type(s)
# Out:
# set

# %%
s = {1,2,3,4,3,4,"syed","Syed","SYED"}

# %%
s #only return unique elements in the list
# Out:
# {1, 2, 3, 4, 'SYED', 'Syed', 'syed'}

# %%
for i in s:
  print (i)
# Out:
# SYED
# 1
# 2
# 3
# 4
# Syed
# syed

# %%
s.add(100)

# %%
s
# Out:
# {1, 100, 2, 3, 4, 'SYED', 'Syed', 'syed'}

# %%
s.pop()
# Out:
# 4

# %%
s.update("Syed")

# %%
s
# Out:
# {100, 'S', 'Syed', 'd', 'e', 'syed', 'y'}

# %%
s.update(["Syed"])

# %%
s
# Out:
# {100, 'S', 'Syed', 'd', 'e', 'syed', 'y'}

# %%
s.remove("Syed")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3802/2822811000.py in <cell line: 0>()
# ----> 1 s.remove("Syed")
#
# KeyError: 'Syed'

# %%
s
# Out:
# {100, 'S', 'd', 'e', 'y'}

# %%
s.remove(101)#THROWS ERROR SINCE THE ELEMENT IS NOT PRESENT
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_3802/2209938664.py in <cell line: 0>()
# ----> 1 s.remove(101)#THROWS ERROR SINCE THE ELEMENT IS NOT PRESENT
#
# KeyError: 101

# %%
s.discard(101)#doest not throw an error though the element is not present in the set.

# %%
#set operations
#Union: combines elements fro, two sets excluding duplicates
#Intesection : Only common elements btw sets
#difference : return the elements that is present in first set and not in second
#symmetric difference : returns elements that are present in either of sets but in

# %%
s1 = {"hiking","reading","coding"}
s2 = {"coding","cooking","reading"}
s1.union(s2)
# Out:
# {'coding', 'cooking', 'hiking', 'reading'}

# %%
s1 | s2 # '|' used for union
# Out:
# {'coding', 'cooking', 'hiking', 'reading'}

# %%
s1 - s2# '-' used for difference
# Out:
# {'hiking'}

# %%
s1 = {"hiking","reading","coding"}
s2 = {"coding","cooking","reading"}

# %%
s1 & s2 # '&' used for intersection
# Out:
# {'coding', 'reading'}

# %%
s1 = {"hiking","reading","coding"}
s2 = {"coding","cooking","reading"}

# %%
s1 ^ s2 # '^' used for symmetric difference
# Out:
# {'cooking', 'hiking'}

# %%
#frozen sets
s = {1,2,3}
s.add(100)

# %%
s
# Out:
# {1, 2, 3, 100}

# %%
#frozen sets>> immutable version of sets, cannot be added or removed any new element.
my_fs = (1,2,3,4)
fs = frozenset(my_fs)
fs
# Out:
# frozenset({1, 2, 3, 4})

# %%
fs.add(6)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3802/2381969887.py in <cell line: 0>()
# ----> 1 fs.add(6)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
#dictionary is a data structure that stores data as a key value pair
#keys are unique and immutable
#Note : dictionaries are unordered. but from Python 3.7 version, dictionaries retain the

# %%
d = {}
type(d)
# Out:
# dict

# %%
d = {"name": "Syed","email": "sygmail.com","contact": 1234}

# %%
d# elements before the ':' is known as key and after ':' is knows as value
# Out:
# {'name': 'Syed', 'email': 'sygmail.com', 'contact': 1234}

# %%
d["name"]
# Out:
# 'Syed'

# %%
d["email"]
# Out:
# 'sygmail.com'
